# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
from geopy.geocoders import Nominatim

# %%
association_bound = gpd.read_file('../data/Neighbor_Ass_Bound.geojson')
print(association_bound.crs)
association_bound.head()
# Out:
# EPSG:4326
#                    name                                           geometry
# 0  Historic Buena Vista  MULTIPOLYGON (((-86.79511 36.17576, -86.79403 ...
# 1        Charlotte Park  MULTIPOLYGON (((-86.87460 36.15758, -86.87317 ...
# 2              Hillwood  MULTIPOLYGON (((-86.87614 36.13554, -86.87583 ...
# 3             East Hill  MULTIPOLYGON (((-86.74659 36.20376, -86.74559 ...
# 4        Cleveland Park  MULTIPOLYGON (((-86.75606 36.18857, -86.75600 ...

# %%
standard_viola = pd.read_csv('../data/Property_Standards_Violations.csv')
print(standard_viola.shape)
standard_viola.head(3)
# Out:
# (112145, 31)
#     Request # Date Received    Property APN   Property Address       City
# 0  22-1294689    04/19/2022  081084A90000CO    1720  6TH AVE N  NASHVILLE  \
# 1  21-1282201    12/03/2021     08302029400    304  CHAPEL AVE  NASHVILLE
# 2  21-1277394    10/05/2021     06100004700  2701  OAKWOOD AVE  NASHVILLE
#
#   State      ZIP                          Property Owner    Complaint Source
# 0    TN  37208.0  O.I.C. 1720 6TH AVENUE NORTH TOWNHOMES                 HUB  \
# 1    TN  37206.0                                    MDHA  INSPECTOR REPORTED
# 2    TN  37207.0                 METRO GOV'T  P  OAKWOOD  INSPECTOR REPORTED
#
#                                     Reported Problem  ... Police Precincts
# 0  Type: Property Violations - Junk and Debris  D...  ...              6.0  \
# 1                                               VROW  ...              2.0
# 2                                                AMV  ...              2.0
#
# ...

# %%
geolocator = Nominatim(user_agent="testing_geospatial.ipynb")
standard_viola['Real_address'] = standard_viola['Property Address'].astype(str) + ", " +  standard_viola['City'].astype(str) + ", " + standard_viola['State'].astype(str) + ", " + standard_viola['ZIP'].astype(str)

# %%
standard_viola = pd.read_csv('../data/Property_Standards_Violations.csv')
print(standard_viola.shape)
standard_viola.head(3)
